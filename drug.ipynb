# %%
import pandas as pd
data=pd.read_csv(r'C:\Users\Dell\Documents\vaishaliml\drug200.csv')

# %%
data
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 0     23   F    HIGH        HIGH   25.355  drugY
# 1     47   M     LOW        HIGH   13.093  drugC
# 2     47   M     LOW        HIGH   10.114  drugC
# 3     28   F  NORMAL        HIGH    7.798  drugX
# 4     61   F     LOW        HIGH   18.043  drugY
# ..   ...  ..     ...         ...      ...    ...
# 195   56   F     LOW        HIGH   11.567  drugC
# 196   16   M     LOW        HIGH   12.006  drugC
# 197   52   M  NORMAL        HIGH    9.894  drugX
# 198   23   M  NORMAL      NORMAL   14.020  drugX
# 199   40   F     LOW      NORMAL   11.349  drugX
#
# [200 rows x 6 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
Age=LabelEncoder()
Sex=LabelEncoder()
BP=LabelEncoder()
Cholesterol=LabelEncoder()
Na_to_K=LabelEncoder()
Drug=LabelEncoder()

# %%
data['Age']=Age.fit_transform(data['Age'])
data['Sex']=Age.fit_transform(data['Sex'])
data['BP']=Age.fit_transform(data['BP'])
data['Cholesterol']=Age.fit_transform(data['Cholesterol'])
data['Na_to_K']=Age.fit_transform(data['Na_to_K'])
data['Drug']=Age.fit_transform(data['Drug'])

# %%
data
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K  Drug
# 0      8    0   0            0      167     4
# 1     30    1   1            0       89     2
# 2     30    1   1            0       43     2
# 3     12    0   2            0       10     3
# 4     44    0   1            0      133     4
# ..   ...  ...  ..          ...      ...   ...
# 195   39    0   1            0       69     2
# 196    1    1   1            0       75     2
# 197   35    1   2            0       36     3
# 198    8    1   2            1      102     3
# 199   24    0   1            1       66     3
#
# [200 rows x 6 columns]

# %%
features_cols=['Age','Sex','BP','Cholesterol','Na_to_K','Drug']
x=data[features_cols]
y=data.Drug

# %%
x
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K  Drug
# 0      8    0   0            0      167     4
# 1     30    1   1            0       89     2
# 2     30    1   1            0       43     2
# 3     12    0   2            0       10     3
# 4     44    0   1            0      133     4
# ..   ...  ...  ..          ...      ...   ...
# 195   39    0   1            0       69     2
# 196    1    1   1            0       75     2
# 197   35    1   2            0       36     3
# 198    8    1   2            1      102     3
# 199   24    0   1            1       66     3
#
# [200 rows x 6 columns]

# %%
y
# Out:
# 0      4
# 1      2
# 2      2
# 3      3
# 4      4
#       ..
# 195    2
# 196    2
# 197    3
# 198    3
# 199    3
# Name: Drug, Length: 200, dtype: int32

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DecisionTreeClassifier(criterion='gini')
# Out:
# DecisionTreeClassifier()

# %%
classifier=DecisionTreeClassifier(criterion='gini')

# %%
classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
classifier.predict(x_test)
# Out:
# array([3, 3, 0, 4, 4, 3, 4, 4, 4, 0, 3, 4, 0, 4, 3, 2, 4, 4, 3, 3, 4, 4,
#        4, 3, 1, 3, 4, 4, 1, 3, 3, 3, 4, 1, 1, 4, 4, 3, 4, 2])

# %%
x_test
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K  Drug
# 79    16    0   1            1       54     3
# 32    32    1   1            1       58     3
# 66    13    1   0            0       83     0
# 163    6    0   0            1      182     4
# 62    50    1   1            1      153     4
# 181   42    0   2            0       96     3
# 143   56    1   0            1      113     4
# 115   34    1   0            0      134     4
# 29    28    1   1            0      132     4
# 150   32    1   0            1       18     0
# 159   18    0   1            1       87     3
# 89    33    0   2            1      130     4
# 78     4    0   0            0       92     0
# 57    24    1   0            0      180     4
# 105   21    1   1            1       21     3
# 18     8    1   1            0        5     2
# 125    4    0   0            1      174     4
# 180    7    0   0            1      160     4
# 152   38    1   2            1        3     3
# ...

# %%
classifier.score(x_test,y_test)
# Out:
# 1.0

# %%
from sklearn import tree
tree.plot_tree(classifier)
# Out:
# [Text(0.6666666666666666, 0.9, 'x[4] <= 107.5\ngini = 0.697\nsamples = 160\nvalue = [20, 12, 14, 41, 73]'),
#  Text(0.5, 0.7, 'x[5] <= 2.5\ngini = 0.68\nsamples = 87\nvalue = [20, 12, 14, 41, 0]'),
#  Text(0.5833333333333333, 0.8, 'True  '),
#  Text(0.3333333333333333, 0.5, 'x[5] <= 0.5\ngini = 0.65\nsamples = 46\nvalue = [20, 12, 14, 0, 0]'),
#  Text(0.16666666666666666, 0.3, 'gini = 0.0\nsamples = 20\nvalue = [20, 0, 0, 0, 0]'),
#  Text(0.5, 0.3, 'x[5] <= 1.5\ngini = 0.497\nsamples = 26\nvalue = [0, 12, 14, 0, 0]'),
#  Text(0.3333333333333333, 0.1, 'gini = 0.0\nsamples = 12\nvalue = [0, 12, 0, 0, 0]'),
#  Text(0.6666666666666666, 0.1, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 14, 0, 0]'),
#  Text(0.6666666666666666, 0.5, 'gini = 0.0\nsamples = 41\nvalue = [0, 0, 0, 41, 0]'),
#  Text(0.8333333333333334, 0.7, 'gini = 0.0\nsamples = 73\nvalue = [0, 0, 0, 0, 73]'),
#  Text(0.75, 0.8, '  False')]
